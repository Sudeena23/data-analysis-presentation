# %% [markdown]
# # **Introduction**
# The Nepal Stock Exchange (NEPSE) is the only stock exchange of Nepal, acting as a platform for the trading of equity securities, bonds, and other financial products. Historical stock data of NEPSE needs to be analyzed in order to know about the trends of the market and for supporting smart investment decisions.
#
# As financial data and analysis software become more accessible, investors and analysts can both utilize data-driven techniques to derive insights from market trends. Historical stock prices of NEPSE between March 2020 and March 2025 are analyzed through time-series techniques and data visualization to better understand market behavior during this period.
#
#
# ### **Objective**
# 1. Load and sanitize historical stock prices of NEPSE (2020–2025).
#
# 2. Plot trends in opening and closing prices over time.
#
# 3. Detect patterns, volatility, and key market changes.
#
# 4. Provide insights for potential future forecasting and investment analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("nepsealpha_export_price_NEPSE_2020-03-16_2025-03-16.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-5-659355600.py in <cell line: 0>()
# ----> 1 df= pd.read_csv("nepsealpha_export_price_NEPSE_2020-03-16_2025-03-16.csv")
#       2
#       3
#
# ...

# %% [markdown]
# # **Data Info**

# %%
df.head()
# Out:
#   Symbol       Date     Open     High      Low    Close Percent Change  \
# 0  NEPSE  3/16/2025  2735.97  2739.55  2693.55  2714.85         -0.79%
# 1  NEPSE  3/12/2025  2718.13  2745.58  2717.29  2736.48          0.63%
# 2  NEPSE  3/11/2025  2752.31  2762.25  2712.74  2719.20         -1.17%
# 3  NEPSE  3/10/2025  2770.17  2791.03  2743.65  2751.42         -0.74%
# 4  NEPSE   3/9/2025  2819.88  2819.92  2766.08  2772.10         -1.64%
#
#               Volume
# 0   6,836,640,407.59
# 1   8,235,268,755.31
# 2   8,391,149,050.00
# 3   8,378,055,057.57
# 4  10,093,654,129.61

# %%
df.tail()
# Out:
#      Symbol       Date     Open     High      Low    Close Percent Change  \
# 1116  NEPSE  3/22/2020  1269.08  1275.42  1246.20  1251.45          0.00%
# 1117  NEPSE  3/19/2020  1249.26  1278.93  1223.04  1269.30          0.00%
# 1118  NEPSE  3/18/2020  1272.10  1286.46  1234.16  1255.80          0.00%
# 1119  NEPSE  3/17/2020  1316.74  1321.26  1266.44  1272.06          0.00%
# 1120  NEPSE  3/16/2020  1312.69  1334.12  1291.67  1316.39          0.00%
#
#                 Volume
# 1116    194,642,984.00
# 1117  1,903,142,008.00
# 1118  1,184,416,878.00
# 1119  1,465,184,656.00
# 1120  1,615,341,877.00

# %%
df.shape
# Out:
# (1121, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          1121 non-null   object
#  1   Date            1121 non-null   object
#  2   Open            1121 non-null   float64
#  3   High            1121 non-null   float64
#  4   Low             1121 non-null   float64
#  5   Close           1121 non-null   float64
#  6   Percent Change  1121 non-null   object
#  7   Volume          1121 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 70.2+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count  1121.000000  1121.000000  1121.000000  1121.000000
# mean   2247.385622  2266.215049  2224.108201  2243.736485
# std     432.107453   435.483287   425.605275   429.461367
# min    1187.250000  1200.640000  1149.730000  1188.700000
# 25%    1960.720000  1974.980000  1937.430000  1958.940000
# 50%    2106.060000  2126.140000  2088.480000  2106.150000
# 75%    2647.760000  2666.190000  2616.980000  2640.680000
# max    3208.530800  3227.110000  3178.250000  3198.190000

# %% [markdown]
# #  **Line Plot of Opening Prices Over**

# %%
# Make sure 'Date' is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort data by date (just in case)
df = df.sort_values(by='Date')

# Plotting the % Change over time
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Open'], color='blue', linewidth=1)
plt.title('Open', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Open')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. shows how the NEPSE market opened each trading day from 2020 to 2025.
#
# 2. An upward trend suggests growing investor confidence, while downward movements may reflect uncertainty or market stress.
#
# 3. Sharp fluctuations could correspond with major national or global events (e.g., COVID-19, political changes).

# %% [markdown]
# # **Line Plot of Closing Prices Over Time**

# %%
# Make sure 'Date' is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort data by date (just in case)
df = df.sort_values(by='Date')

# Plotting the % Change over time
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Close'], color='blue', linewidth=1)
plt.title('Close', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Close')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Reflects the end-of-day market value, providing a better indication of long-term market direction.
#
# 2. Trends in closing prices help identify overall market growth, corrections, or downturns.
#
# 3. Comparing closing prices across time can reveal recovery periods or prolonged bearish phases.

# %% [markdown]
# # **Conclusion**
#
# The analysis of NEPSE stock market data from 2020 to 2025 reveals valuable insights into market behavior over time:
#
# **Opening and Closing Prices** show clear trends that reflect investor
# sentiment, economic conditions, and external events.
#
# **Fluctuations in price patterns** suggest periods of high volatility, possibly linked to global disruptions like the COVID-19 pandemic or local economic developments.
#
# **Upward movements** in closing prices may indicate phases of market recovery and growth, while downward trends point to correction periods or declining confidence.
#
# These visualizations help investors and analysts understand how the market has evolved and provide a foundation for further financial modeling or forecasting.
